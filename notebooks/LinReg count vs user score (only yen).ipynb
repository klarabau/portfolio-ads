# %% [markdown]
# # Input
# After creating my first model on the whole dataset, I wanted to focus it only on Yen to make the result less biased due to the imbalance between threshold methods.

# %%
# Importing libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from ml import *
from sklearn.preprocessing import PolynomialFeatures

# %%
# Creating dataframe 
df = pd.read_csv('/datc/nano/notebooks/Target variable & Features (V3).csv')

# %%
# Extract only yen values
df_yen = df[df['Threshold method'] =='yen']
df_yen
# Out:
#                            Id Threshold method  Threshold: area spread  \
# 0    5f11480a2d99b96663b97fdb              yen                0.265214
# 2    5f15419a79e27502789bbbd1              yen                0.154306
# 3    5f27c1cced3aa3f0c260b246              yen                0.012426
# 4    5f30f7b9ed3aa3f0c260b563              yen                0.408562
# 5    5f30fafded3aa3f0c260b6bc              yen                0.035861
# 6    5f3262b8ed3aa3f0c260b76d              yen                0.265214
# 7    5f326347ed3aa3f0c260b7a4              yen                0.271761
# 8    5f3276efed3aa3f0c260b800              yen                0.061846
# 9    5f3277c9ed3aa3f0c260b874              yen                0.531565
# 10   5f32786ded3aa3f0c260b912              yen                0.211002
# 11   5f3278d5ed3aa3f0c260b9a1              yen                1.268999
# 12   5f32796aed3aa3f0c260ba10              yen                0.265214
# 13   5f327a1eed3aa3f0c260ba2f              yen                0.921402
# 14   5f327c39ed3aa3f0c260bb45              yen                1.056254
# 15   5f327c97ed3aa3f0c260bb87              yen                1.018658
# 16   5f32892a8d62faf2c4d4df24              yen                0.634746
# 17   5f3fe00e8d62faf2c4d4df91              yen                0.185835
# 19   5f46289c8d62faf2c4d4e101              yen                1.045751
# 21   5f4629238d62faf2c4d4e1a2              yen                0.224389
# 23   5f4629d78d62faf2c4d4e268              yen                0.482146
# 24   5f48ea4d7495efe38e28c2bd              yen                0.043063
# 26   5f48ed957495efe38e28c363              yen                0.205450
# 28   5f48ee097495efe38e28c408              yen                1.017542
# 29   5f48ee847495efe38e28c50b              yen                0.288264
# 32   5f49022c298cf94b214e880d              yen                0.034957
# 34   5f491152298cf94b214e88ca              yen                0.034162
# 36   5f4911a5298cf94b214e8967              yen                0.063672
# 39   5f491229298cf94b214e8ab4              yen                0.034162
# 41   5f491278298cf94b214e8b6e              yen                1.018658
# 42   5f4912a9298cf94b214e8bf5              yen                1.018658
# 44   5f491414298cf94b214e8cf6              yen                0.063439
# 48   5f491885298cf94b214e8f40              yen                0.997161
# 49   5f4918ae298cf94b214e8fbf              yen                0.038498
# 50   5f491b72298cf94b214e908d              yen                0.823305
# 51   5f491c1d298cf94b214e90a4              yen                0.536621
# 52   5f491d50298cf94b214e90d3              yen                0.641074
# 54   5f491dfa298cf94b214e9118              yen                0.509179
# 55   5f4ca588298cf94b214e9180              yen                0.033373
# 61   5f4ca6dc298cf94b214e93ef              yen                0.022708
# 62   5f4ca6f6298cf94b214e9406              yen                0.050846
# 72   5f4ca909298cf94b214e96cb              yen                0.021808
# 73   5f4ca925298cf94b214e96e4              yen                0.347624
# 79   5f4caa47298cf94b214e9991              yen                0.238862
# 80   5f4caa60298cf94b214e99a8              yen                0.711877
# 87   5f4cab36298cf94b214e9b52              yen                0.544224
# 93   5f4cabd2298cf94b214e9c91              yen                0.244103
# 94   5f4cabe3298cf94b214e9ca8              yen                0.071380
# 104  5f4cb430298cf94b214e9eb3              yen                0.242782
# 106  5f4cb467298cf94b214e9efd              yen                0.296216
# 107  5f4cb4b7298cf94b214e9f3b              yen                0.832507
# 111  5f4cb63d298cf94b214ea091              yen                0.587111
# 112  5f4cb652298cf94b214ea0a8              yen                0.171722
# 39               2.802198               0.193133           3
# 41               4.451529               0.097586           4
# 42               4.451529               0.097586           5
# 44               1.821429               0.123413           4
# 48               3.826177               0.095296           3
# 49               1.888889               0.129390           4
# 50               1.491228               0.127126           4
# 51               2.833333               0.185980           1
# 52               4.811321               0.183952           9
# 54               4.112903               0.188688           9
# 55               2.575758               0.209572           9
# 61               2.833333               0.180097           3
# 62               4.112903               0.365704           8
# 72               5.666667               0.234065          10
# 73               1.783217               0.055790           1
# 79               7.552946               0.266064           6
# 80               3.863636               0.134479          10
# 87               3.000000               0.304331           8
# 93               3.541667               0.155156           9
# 94               3.148148               0.290850           8
# 104              1.821429               0.105222           2
# 106              2.833333               0.357213           8
# 107              2.602041               0.137976           8
# 111              5.848502               0.022235           1
# 112              3.493151               0.415127           6
# 113              5.736328               0.019586           1
# 117              1.808511               0.074534           2
# 118              4.180328               0.232935           8
# 119              1.491228               0.127432           2
# 123              2.431401               0.082923           2
# 125              7.083333               0.433293           5

# %%
# Specifying x and y
X = df_yen[['Threshold: count']]
y = df_yen[['User score']]

# %%
# Plotting data
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.show()

# %%
# Creating model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Visualizing model
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X), c='orange')
plt.show()

# %%
# Magnifyer
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X), c='orange')
plt.xlim(0,50)
plt.show()

# %%
# Creating 2nd order
poly = PolynomialFeatures(degree=2, include_bias=False)
X2 = poly.fit_transform(X)

# %%
# Creating 2nd order model
model = LinearRegression()
model.fit(X2, y)
# Out:
# LinearRegression()

# %%
# Visualizing 2nd order model
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X2), c='orange')
plt.show()

# %%
# Magnifyer
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X2), c='orange')
plt.xlim(0,50)
plt.show()

# %%
# Creating 3rd order
poly = PolynomialFeatures(degree=3, include_bias=False)
X3 = poly.fit_transform(X)

# %%
# Creating 3rd order model
model = LinearRegression()
model.fit(X3, y)
# Out:
# LinearRegression()

# %%
# Visualizing 3rd order model
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X3), c='orange')
plt.show()

# %%
# Magnifyer
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X3), c='orange')
plt.xlim(0,50)
plt.show()

# %%
# Creating 4th order
poly = PolynomialFeatures(degree=4, include_bias=False)
X4 = poly.fit_transform(X)

# %%
# Creating 4th order model
model = LinearRegression()
model.fit(X4, y)
# Out:
# LinearRegression()

# %%
# Visualizing 4th order model
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X4), c='orange')
plt.show()

# %%
# Magnifyer
df_yen.plot(kind='scatter', x='Threshold: count', y='User score', title='User score vs. count of particles')
plt.scatter(X, model.predict(X4), c='orange')
plt.xlim(0,50)
plt.show()

# %%
model.coef_
# Out:
# array([[ 0.00607653, -0.00002546,  0.00000008, -0.        ]])

# %%
model.intercept_
# Out:
# array([5.20670686])

# %%
y.sum()/len(y)
# Out:
# User score    5.3125
# dtype: float64
